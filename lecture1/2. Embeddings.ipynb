# %% [markdown]
# # Word2vec

# %% [markdown]
# ## Theory

# %% [markdown]
# Word2Vec is vector representation of word. The word2vec tool takes a text corpus as input and produces the word vectors as output. It first constructs a vocabulary from the training text data and then learns vector representation of words. The resulting word vector file can be used as features in many natural language processing and machine learning applications.
#
# A simple way to investigate the learned representations is to find the closest words for a user-specified word. The distance tool serves that purpose. For example, if you enter 'france', distance will display the most similar words and their distances to 'france', which should look like:
#
# ```
#
# Word Cosine distance
#
#             spain              0.678515
#           belgium              0.665923
#       netherlands              0.652428
#             italy              0.633130
#       switzerland              0.622323
#        luxembourg              0.610033
#          portugal              0.577154
#            russia              0.571507
#           germany              0.563291
#         catalonia              0.534176
# ```
#
# There are two main learning algorithms in word2vec : continuous bag-of-words and continuous skip-gram. Both algorithms learn the representation of a word that is useful for prediction of other words in the sentence.
# Skipgram - predict context words given the target (position independent)
# CBoW - predict target word from the bag of words context
#
# Training Methods - Hierarchical Softmax and Negative Sampling
#
# Skip-gram: works well with small amount of the training data, represents well even rare words or phrases.
# CBOW: several times faster to train than the skip-gram, slightly better accuracy for the frequent words

# %% [markdown]
# #### Facts:
# <li>Predictive method, not a count-based as Glove or BagOfWords</li>
# <li>architecture: skip-gram (slower, better for infrequent words, use “Negative Sampling”) vs CBOW (fast)</li>
# <li>the training algorithm: hierarchical softmax (better for infrequent words) vs negative sampling (better for frequent words, better with low dimensional vectors)</li>
# <li>sub-sampling of frequent words: can improve both accuracy and speed for large data sets (useful values are in range \begin{equation*}10^{-3} \text{  to  }10^{-5}\end{equation*}</li>
# <li>dimensionality of the word vectors: usually more is better, but not always</li>
# <li>context (window) size: for skip-gram usually around 10, for CBOW around 5</li>
# <li>google pretrained model exists</li>

# %% [markdown]
# #### Useful links
# <li>https://www.tensorflow.org/tutorials/word2vec/</li>
# <li>https://code.google.com/archive/p/word2vec/ </li>
# <li>https://radimrehurek.com/gensim/models/word2vec.html - gensim usage</li>
# <li>https://rare-technologies.com/word2vec-tutorial/ - creator of gensim</li>
# <li>https://ru.wikipedia.org/wiki/Дистрибутивная_семантика</li>
# <li>https://otvet.mail.ru/question/34643535 </li>
# <li>http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf</li>
# <li>http://sebastianruder.com/word-embeddings-softmax/index.html#negativesampling</li>
# <li>http://mccormickml.com/assets/word2vec/Alex_Minnaar_Word2Vec_Tutorial_Part_II_The_Continuous_Bag-of-Words_Model.pdf</li>
# <li>http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/</li>
# <li>https://github.com/jdwittenauer/ipython-notebooks/blob/master/notebooks/tensorflow/Tensorflow-5-Word2Vec.ipynb</li>

# %% [markdown]
# # Practice

# %%
#download wordnet
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
wn.synsets('awful')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alexruppelt/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [Synset('atrocious.s.02'),
#  Synset('awful.s.02'),
#  Synset('nasty.a.01'),
#  Synset('awed.s.01'),
#  Synset('frightful.s.02'),
#  Synset('amazing.s.02'),
#  Synset('terribly.r.01')]

# %%
for ss in wn.synsets('awful'):
    print(ss)
    for sim in ss.similar_tos():
        print ('    {}'.format(sim))
# Out:
# Synset('atrocious.s.02')
#     Synset('bad.a.01')
# Synset('awful.s.02')
#     Synset('alarming.a.01')
# Synset('nasty.a.01')
#     Synset('dirty.s.03')
#     Synset('grotty.s.01')
#     Synset('hateful.s.02')
# Synset('awed.s.01')
#     Synset('reverent.a.01')
# Synset('frightful.s.02')
#     Synset('extraordinary.a.01')
# Synset('amazing.s.02')
#     Synset('impressive.a.01')
# Synset('terribly.r.01')

# %%
wn.synsets('badass')
# Out:
# []

# %%
import re
import logging
import time

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

import numpy as np
import pandas as pd      

from gensim.models import Word2Vec

import nltk
# nltk.download()  # Download text data sets, including stop words
from nltk.corpus import stopwords # Import the stop word list
# Out:
# Using TensorFlow backend.
# 2017-07-18 16:06:13,133 : INFO : 'pattern' package not found; tag filters are not available for English

# %% [markdown]
# # Import and preprocess Reviews

# %%
print("Review reading...")
# Reading data
file_data = pd.read_csv("../data/movie_reviews.csv", encoding = 'utf8')
reviews = file_data['text']
print("Reading finished")
# Out:
# Review reading...
# Reading finished

# %% [markdown]
# # Tokenize Reviews

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

def review_to_wordlist( review, remove_stopwords=False ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    #review_text = BeautifulSoup(review, "lxml").get_text()
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# Define a function to split a review into parsed sentences
def review_to_sentences( review, tokenizer, remove_stopwords=False ):
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence, \
              remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
# %%time
sentences = []  # Initialize an empty list of sentences
print("Parsing sentences from training set")
for i, review in enumerate(reviews):
    sentences += review_to_sentences(review, tokenizer)
    
print("Preprocessing completed")
# Out:
# Parsing sentences from training set
# Preprocessing completed
# CPU times: user 34.1 s, sys: 693 ms, total: 34.8 s
# Wall time: 34.9 s

# %% [markdown]
# #  Train model

# %%
print(sentences[0])
# Out:
# ['to', 'an', 'entire', 'generation', 'of', 'filmgoers', 'it', 'just', 'might', 'represent', 'the', 'most', 'significant', 'leap', 'in', 'storytelling', 'that', 'they', 'will', 'ever', 'see']

# %%
# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 20    # Minimum word count                        
num_workers = 8       # Number of threads to run in parallel
context = 5          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words
training_algorithm = 1 # 0-CBOW, 1-SkipGram

# %%
# %%time
# Initialize and train the model (this will take some time)
print("Training model...")
    
model = Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling, \
            sg=training_algorithm)
# Out:
# 2017-07-18 16:06:48,929 : INFO : collecting all words and their counts
# 2017-07-18 16:06:48,931 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-07-18 16:06:48,988 : INFO : PROGRESS: at sentence #10000, processed 158749 words, keeping 16127 word types
# 2017-07-18 16:06:49,042 : INFO : PROGRESS: at sentence #20000, processed 323403 words, keeping 22922 word types
# 2017-07-18 16:06:49,089 : INFO : PROGRESS: at sentence #30000, processed 485455 words, keeping 27575 word types
# Training model...
# 2017-07-18 16:06:49,136 : INFO : PROGRESS: at sentence #40000, processed 644047 words, keeping 31316 word types
# 2017-07-18 16:06:49,181 : INFO : PROGRESS: at sentence #50000, processed 804801 words, keeping 34762 word types
# 2017-07-18 16:06:49,226 : INFO : PROGRESS: at sentence #60000, processed 967531 words, keeping 38059 word types
# 2017-07-18 16:06:49,272 : INFO : PROGRESS: at sentence #70000, processed 1134615 words, keeping 41245 word types
# 2017-07-18 16:06:49,324 : INFO : PROGRESS: at sentence #80000, processed 1302144 words, keeping 43911 word types
# 2017-07-18 16:06:49,371 : INFO : PROGRESS: at sentence #90000, processed 1468718 words, keeping 46384 word types
# 2017-07-18 16:06:49,421 : INFO : PROGRESS: at sentence #100000, processed 1637721 words, keeping 48888 word types
# 2017-07-18 16:06:49,473 : INFO : PROGRESS: at sentence #110000, processed 1814034 words, keeping 51595 word types
# 2017-07-18 16:06:49,526 : INFO : PROGRESS: at sentence #120000, processed 1996532 words, keeping 54361 word types
# 2017-07-18 16:06:49,582 : INFO : PROGRESS: at sentence #130000, processed 2203889 words, keeping 56432 word types
# 2017-07-18 16:06:49,638 : INFO : PROGRESS: at sentence #140000, processed 2417942 words, keeping 58431 word types
# 2017-07-18 16:06:49,690 : INFO : PROGRESS: at sentence #150000, processed 2625439 words, keeping 60167 word types
# 2017-07-18 16:06:49,744 : INFO : PROGRESS: at sentence #160000, processed 2836004 words, keeping 61930 word types
# 2017-07-18 16:06:49,803 : INFO : PROGRESS: at sentence #170000, processed 3049777 words, keeping 63635 word types
# 2017-07-18 16:06:49,858 : INFO : PROGRESS: at sentence #180000, processed 3255875 words, keeping 65021 word types
# 2017-07-18 16:06:49,913 : INFO : PROGRESS: at sentence #190000, processed 3464024 words, keeping 66577 word types
# 2017-07-18 16:06:49,972 : INFO : PROGRESS: at sentence #200000, processed 3675671 words, keeping 67999 word types
# 2017-07-18 16:06:50,029 : INFO : PROGRESS: at sentence #210000, processed 3887503 words, keeping 69421 word types
# 2017-07-18 16:06:50,087 : INFO : PROGRESS: at sentence #220000, processed 4092646 words, keeping 70739 word types
# 2017-07-18 16:06:50,142 : INFO : PROGRESS: at sentence #230000, processed 4307138 words, keeping 72157 word types
# 2017-07-18 16:06:50,200 : INFO : PROGRESS: at sentence #240000, processed 4521155 words, keeping 73460 word types
# 2017-07-18 16:06:50,254 : INFO : PROGRESS: at sentence #250000, processed 4733947 words, keeping 74835 word types
# 2017-07-18 16:06:50,311 : INFO : PROGRESS: at sentence #260000, processed 4954605 words, keeping 76180 word types
# 2017-07-18 16:06:50,370 : INFO : PROGRESS: at sentence #270000, processed 5177072 words, keeping 77659 word types
# 2017-07-18 16:06:50,426 : INFO : PROGRESS: at sentence #280000, processed 5396617 words, keeping 78992 word types
# 2017-07-18 16:06:50,492 : INFO : PROGRESS: at sentence #290000, processed 5626364 words, keeping 80266 word types
# 2017-07-18 16:06:50,550 : INFO : PROGRESS: at sentence #300000, processed 5847612 words, keeping 81568 word types
# 2017-07-18 16:06:50,607 : INFO : PROGRESS: at sentence #310000, processed 6067287 words, keeping 82740 word types
# 2017-07-18 16:06:50,661 : INFO : PROGRESS: at sentence #320000, processed 6290201 words, keeping 83880 word types
# 2017-07-18 16:06:50,722 : INFO : PROGRESS: at sentence #330000, processed 6517042 words, keeping 85108 word types
# 2017-07-18 16:06:50,778 : INFO : PROGRESS: at sentence #340000, processed 6745692 words, keeping 86222 word types
# 2017-07-18 16:06:50,846 : INFO : PROGRESS: at sentence #350000, processed 6967948 words, keeping 87467 word types
# 2017-07-18 16:06:50,918 : INFO : PROGRESS: at sentence #360000, processed 7180730 words, keeping 88417 word types
# 2017-07-18 16:06:51,002 : INFO : PROGRESS: at sentence #370000, processed 7409476 words, keeping 89582 word types
# 2017-07-18 16:06:51,070 : INFO : PROGRESS: at sentence #380000, processed 7637453 words, keeping 90643 word types
# 2017-07-18 16:06:51,135 : INFO : PROGRESS: at sentence #390000, processed 7855270 words, keeping 91705 word types
# 2017-07-18 16:06:51,201 : INFO : PROGRESS: at sentence #400000, processed 8061464 words, keeping 92645 word types
# 2017-07-18 16:06:51,264 : INFO : PROGRESS: at sentence #410000, processed 8270750 words, keeping 93549 word types
# 2017-07-18 16:06:51,331 : INFO : PROGRESS: at sentence #420000, processed 8481802 words, keeping 94577 word types
# 2017-07-18 16:06:51,397 : INFO : PROGRESS: at sentence #430000, processed 8688041 words, keeping 95475 word types
# 2017-07-18 16:06:51,462 : INFO : PROGRESS: at sentence #440000, processed 8898248 words, keeping 96355 word types
# 2017-07-18 16:06:51,527 : INFO : PROGRESS: at sentence #450000, processed 9109345 words, keeping 97257 word types
# 2017-07-18 16:06:51,603 : INFO : PROGRESS: at sentence #460000, processed 9321398 words, keeping 98352 word types
# 2017-07-18 16:06:51,673 : INFO : PROGRESS: at sentence #470000, processed 9536563 words, keeping 99327 word types
# 2017-07-18 16:06:51,740 : INFO : PROGRESS: at sentence #480000, processed 9750268 words, keeping 100140 word types
# 2017-07-18 16:06:51,804 : INFO : PROGRESS: at sentence #490000, processed 9954910 words, keeping 101056 word types
# 2017-07-18 16:06:51,868 : INFO : PROGRESS: at sentence #500000, processed 10162370 words, keeping 101799 word types
# 2017-07-18 16:06:51,935 : INFO : PROGRESS: at sentence #510000, processed 10373276 words, keeping 102626 word types
# 2017-07-18 16:06:51,998 : INFO : PROGRESS: at sentence #520000, processed 10583779 words, keeping 103372 word types
# 2017-07-18 16:06:52,064 : INFO : PROGRESS: at sentence #530000, processed 10808009 words, keeping 104316 word types
# 2017-07-18 16:06:52,126 : INFO : PROGRESS: at sentence #540000, processed 11036484 words, keeping 105207 word types
# 2017-07-18 16:06:52,196 : INFO : PROGRESS: at sentence #550000, processed 11263076 words, keeping 106186 word types
# 2017-07-18 16:06:52,268 : INFO : PROGRESS: at sentence #560000, processed 11483230 words, keeping 107144 word types
# 2017-07-18 16:06:52,344 : INFO : PROGRESS: at sentence #570000, processed 11706002 words, keeping 107980 word types
# 2017-07-18 16:06:52,414 : INFO : PROGRESS: at sentence #580000, processed 11932252 words, keeping 108845 word types
# 2017-07-18 16:06:52,487 : INFO : PROGRESS: at sentence #590000, processed 12164804 words, keeping 109837 word types
# 2017-07-18 16:06:52,557 : INFO : PROGRESS: at sentence #600000, processed 12391118 words, keeping 110791 word types
# 2017-07-18 16:06:52,625 : INFO : PROGRESS: at sentence #610000, processed 12618050 words, keeping 111617 word types
# 2017-07-18 16:06:52,702 : INFO : PROGRESS: at sentence #620000, processed 12842323 words, keeping 112484 word types
# 2017-07-18 16:06:52,767 : INFO : PROGRESS: at sentence #630000, processed 13067017 words, keeping 113206 word types
# 2017-07-18 16:06:52,840 : INFO : PROGRESS: at sentence #640000, processed 13292218 words, keeping 114154 word types
# 2017-07-18 16:06:52,912 : INFO : PROGRESS: at sentence #650000, processed 13518303 words, keeping 115010 word types
# 2017-07-18 16:06:52,979 : INFO : collected 115577 word types from a corpus of 13693400 raw words and 657827 sentences
# 2017-07-18 16:06:52,980 : INFO : Loading a fresh vocabulary
# 2017-07-18 16:06:53,141 : INFO : min_count=20 retains 21976 unique words (19% of original 115577, drops 93601)
# 2017-07-18 16:06:53,142 : INFO : min_count=20 leaves 13368251 word corpus (97% of original 13693400, drops 325149)
# 2017-07-18 16:06:53,217 : INFO : deleting the raw counts dictionary of 115577 items
# 2017-07-18 16:06:53,224 : INFO : sample=0.001 downsamples 47 most-common words
# 2017-07-18 16:06:53,225 : INFO : downsampling leaves estimated 9983483 word corpus (74.7% of prior 13368251)
# 2017-07-18 16:06:53,226 : INFO : estimated required memory for 21976 words and 300 dimensions: 63730400 bytes
# 2017-07-18 16:06:53,326 : INFO : resetting layer weights
# 2017-07-18 16:06:53,730 : INFO : training model with 8 workers on 21976 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2017-07-18 16:06:54,760 : INFO : PROGRESS: at 0.64% examples, 245980 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:06:55,777 : INFO : PROGRESS: at 1.57% examples, 299552 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:06:56,780 : INFO : PROGRESS: at 2.39% examples, 308850 words/s, in_qsize 16, out_qsize 2
# 2017-07-18 16:06:57,808 : INFO : PROGRESS: at 3.28% examples, 320262 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:06:58,810 : INFO : PROGRESS: at 3.99% examples, 321618 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:06:59,812 : INFO : PROGRESS: at 4.60% examples, 320174 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:00,815 : INFO : PROGRESS: at 5.27% examples, 322269 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:01,819 : INFO : PROGRESS: at 5.98% examples, 326420 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:02,827 : INFO : PROGRESS: at 6.66% examples, 328047 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:03,836 : INFO : PROGRESS: at 7.33% examples, 329177 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:04,842 : INFO : PROGRESS: at 8.00% examples, 330820 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:05,890 : INFO : PROGRESS: at 8.64% examples, 330310 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:06,898 : INFO : PROGRESS: at 9.29% examples, 331456 words/s, in_qsize 16, out_qsize 2
# 2017-07-18 16:07:07,917 : INFO : PROGRESS: at 9.92% examples, 331139 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:08,953 : INFO : PROGRESS: at 10.58% examples, 331896 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:09,973 : INFO : PROGRESS: at 11.22% examples, 332044 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:10,986 : INFO : PROGRESS: at 11.86% examples, 332328 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:12,011 : INFO : PROGRESS: at 12.57% examples, 333245 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:13,012 : INFO : PROGRESS: at 13.21% examples, 332606 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:07:14,046 : INFO : PROGRESS: at 13.80% examples, 330407 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:07:15,048 : INFO : PROGRESS: at 14.43% examples, 329935 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:16,098 : INFO : PROGRESS: at 14.94% examples, 325867 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:17,101 : INFO : PROGRESS: at 15.42% examples, 322197 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:18,139 : INFO : PROGRESS: at 15.89% examples, 318355 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:19,144 : INFO : PROGRESS: at 16.36% examples, 315754 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:20,149 : INFO : PROGRESS: at 16.76% examples, 311987 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:21,153 : INFO : PROGRESS: at 17.35% examples, 311962 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:22,161 : INFO : PROGRESS: at 17.84% examples, 310331 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:23,206 : INFO : PROGRESS: at 18.32% examples, 308151 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:24,281 : INFO : PROGRESS: at 18.81% examples, 305843 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:25,314 : INFO : PROGRESS: at 19.29% examples, 304122 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:26,314 : INFO : PROGRESS: at 19.85% examples, 304126 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:27,332 : INFO : PROGRESS: at 20.48% examples, 302759 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:28,341 : INFO : PROGRESS: at 21.12% examples, 301139 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:07:29,376 : INFO : PROGRESS: at 21.93% examples, 301220 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:30,385 : INFO : PROGRESS: at 22.54% examples, 299694 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:31,387 : INFO : PROGRESS: at 23.27% examples, 299654 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:32,407 : INFO : PROGRESS: at 23.96% examples, 300032 words/s, in_qsize 16, out_qsize 2
# 2017-07-18 16:07:33,413 : INFO : PROGRESS: at 24.67% examples, 301437 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:34,463 : INFO : PROGRESS: at 25.33% examples, 301910 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:35,484 : INFO : PROGRESS: at 25.99% examples, 302382 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:07:36,508 : INFO : PROGRESS: at 26.61% examples, 302503 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:37,513 : INFO : PROGRESS: at 27.28% examples, 303399 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:38,533 : INFO : PROGRESS: at 27.82% examples, 302676 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:39,544 : INFO : PROGRESS: at 28.31% examples, 301678 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:40,550 : INFO : PROGRESS: at 28.74% examples, 300136 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:41,561 : INFO : PROGRESS: at 29.22% examples, 299099 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:42,595 : INFO : PROGRESS: at 29.86% examples, 299742 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:43,685 : INFO : PROGRESS: at 30.51% examples, 300292 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:07:44,696 : INFO : PROGRESS: at 31.23% examples, 301726 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:45,733 : INFO : PROGRESS: at 31.67% examples, 300317 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:46,742 : INFO : PROGRESS: at 32.29% examples, 300516 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:47,760 : INFO : PROGRESS: at 32.92% examples, 300662 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:07:48,764 : INFO : PROGRESS: at 33.41% examples, 299685 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:49,835 : INFO : PROGRESS: at 33.90% examples, 298391 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:50,854 : INFO : PROGRESS: at 34.35% examples, 297161 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:07:51,857 : INFO : PROGRESS: at 34.77% examples, 295674 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:52,882 : INFO : PROGRESS: at 35.28% examples, 294873 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:53,925 : INFO : PROGRESS: at 35.76% examples, 293766 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:54,938 : INFO : PROGRESS: at 36.15% examples, 292341 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:55,973 : INFO : PROGRESS: at 36.47% examples, 290271 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:07:56,986 : INFO : PROGRESS: at 36.87% examples, 289071 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:57,988 : INFO : PROGRESS: at 37.29% examples, 287960 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:07:58,999 : INFO : PROGRESS: at 37.70% examples, 286953 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:07:59,999 : INFO : PROGRESS: at 38.07% examples, 285675 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:01,030 : INFO : PROGRESS: at 38.58% examples, 285385 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:02,032 : INFO : PROGRESS: at 39.07% examples, 285028 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:03,071 : INFO : PROGRESS: at 39.62% examples, 285048 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:04,099 : INFO : PROGRESS: at 40.38% examples, 285859 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:05,106 : INFO : PROGRESS: at 41.34% examples, 287067 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:06,123 : INFO : PROGRESS: at 42.31% examples, 288387 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:07,185 : INFO : PROGRESS: at 43.31% examples, 289768 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:08,191 : INFO : PROGRESS: at 44.02% examples, 290353 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:09,196 : INFO : PROGRESS: at 44.62% examples, 290456 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:10,211 : INFO : PROGRESS: at 45.19% examples, 290415 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:11,222 : INFO : PROGRESS: at 45.82% examples, 290675 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:12,241 : INFO : PROGRESS: at 46.54% examples, 291561 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:13,264 : INFO : PROGRESS: at 47.30% examples, 292675 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:14,269 : INFO : PROGRESS: at 48.03% examples, 293719 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:08:15,288 : INFO : PROGRESS: at 48.76% examples, 294852 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:16,290 : INFO : PROGRESS: at 49.41% examples, 295479 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:17,310 : INFO : PROGRESS: at 50.13% examples, 296457 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:18,312 : INFO : PROGRESS: at 50.84% examples, 297406 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:19,346 : INFO : PROGRESS: at 51.54% examples, 298213 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:20,366 : INFO : PROGRESS: at 52.28% examples, 299074 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:21,370 : INFO : PROGRESS: at 53.00% examples, 299731 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:08:22,400 : INFO : PROGRESS: at 53.76% examples, 300615 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:23,404 : INFO : PROGRESS: at 54.40% examples, 300906 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:24,413 : INFO : PROGRESS: at 55.16% examples, 301746 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:25,423 : INFO : PROGRESS: at 55.82% examples, 302083 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:26,426 : INFO : PROGRESS: at 56.37% examples, 302027 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:27,441 : INFO : PROGRESS: at 57.07% examples, 302780 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:28,468 : INFO : PROGRESS: at 57.79% examples, 303564 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:08:29,488 : INFO : PROGRESS: at 58.49% examples, 304340 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:30,520 : INFO : PROGRESS: at 59.17% examples, 304843 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:31,526 : INFO : PROGRESS: at 59.84% examples, 305417 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:32,534 : INFO : PROGRESS: at 60.85% examples, 306523 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:33,537 : INFO : PROGRESS: at 61.83% examples, 307260 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:34,564 : INFO : PROGRESS: at 62.89% examples, 308320 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:35,565 : INFO : PROGRESS: at 63.77% examples, 309076 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:36,591 : INFO : PROGRESS: at 64.54% examples, 309751 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:08:37,604 : INFO : PROGRESS: at 65.29% examples, 310386 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:38,621 : INFO : PROGRESS: at 66.01% examples, 310853 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:39,640 : INFO : PROGRESS: at 66.78% examples, 311516 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:40,643 : INFO : PROGRESS: at 67.52% examples, 312146 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:41,656 : INFO : PROGRESS: at 68.25% examples, 312781 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:42,686 : INFO : PROGRESS: at 68.97% examples, 313351 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:43,696 : INFO : PROGRESS: at 69.68% examples, 313902 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:44,733 : INFO : PROGRESS: at 70.40% examples, 314487 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:45,808 : INFO : PROGRESS: at 71.13% examples, 314898 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:46,838 : INFO : PROGRESS: at 71.82% examples, 315298 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:08:47,841 : INFO : PROGRESS: at 72.51% examples, 315531 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:48,845 : INFO : PROGRESS: at 73.19% examples, 315761 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:49,866 : INFO : PROGRESS: at 73.92% examples, 316194 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:50,874 : INFO : PROGRESS: at 74.66% examples, 316719 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:51,927 : INFO : PROGRESS: at 75.41% examples, 317046 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:52,928 : INFO : PROGRESS: at 76.14% examples, 317562 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:08:53,980 : INFO : PROGRESS: at 76.82% examples, 317927 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:08:55,007 : INFO : PROGRESS: at 77.55% examples, 318407 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:56,011 : INFO : PROGRESS: at 78.21% examples, 318751 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:57,021 : INFO : PROGRESS: at 78.91% examples, 319200 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:58,039 : INFO : PROGRESS: at 79.59% examples, 319505 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:08:59,042 : INFO : PROGRESS: at 80.41% examples, 319974 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:00,049 : INFO : PROGRESS: at 81.37% examples, 320380 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:01,056 : INFO : PROGRESS: at 82.29% examples, 320718 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:02,074 : INFO : PROGRESS: at 83.29% examples, 321346 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:03,124 : INFO : PROGRESS: at 84.06% examples, 321551 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:04,143 : INFO : PROGRESS: at 84.82% examples, 321949 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:05,158 : INFO : PROGRESS: at 85.54% examples, 322243 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:06,187 : INFO : PROGRESS: at 86.32% examples, 322712 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:09:07,190 : INFO : PROGRESS: at 87.00% examples, 322857 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:08,244 : INFO : PROGRESS: at 87.78% examples, 323312 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:09:09,246 : INFO : PROGRESS: at 88.53% examples, 323856 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:10,269 : INFO : PROGRESS: at 89.18% examples, 323979 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:11,337 : INFO : PROGRESS: at 89.94% examples, 324409 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 16:09:12,344 : INFO : PROGRESS: at 90.67% examples, 324875 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:13,383 : INFO : PROGRESS: at 91.35% examples, 325050 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:14,394 : INFO : PROGRESS: at 92.11% examples, 325502 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:15,448 : INFO : PROGRESS: at 92.86% examples, 325761 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:16,491 : INFO : PROGRESS: at 93.61% examples, 326040 words/s, in_qsize 15, out_qsize 1
# 2017-07-18 16:09:17,494 : INFO : PROGRESS: at 94.30% examples, 326201 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:18,503 : INFO : PROGRESS: at 95.07% examples, 326600 words/s, in_qsize 16, out_qsize 0
# 2017-07-18 16:09:19,511 : INFO : PROGRESS: at 95.79% examples, 326845 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:20,524 : INFO : PROGRESS: at 96.52% examples, 327308 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:09:21,541 : INFO : PROGRESS: at 97.22% examples, 327562 words/s, in_qsize 16, out_qsize 1
# 2017-07-18 16:09:22,548 : INFO : PROGRESS: at 97.90% examples, 327833 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:23,560 : INFO : PROGRESS: at 98.60% examples, 328132 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:24,561 : INFO : PROGRESS: at 99.30% examples, 328457 words/s, in_qsize 15, out_qsize 0
# 2017-07-18 16:09:25,444 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2017-07-18 16:09:25,464 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-07-18 16:09:25,465 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-07-18 16:09:25,478 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-07-18 16:09:25,483 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-07-18 16:09:25,497 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-07-18 16:09:25,516 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-07-18 16:09:25,543 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-07-18 16:09:25,544 : INFO : training on 68467000 raw words (49915419 effective words) took 151.8s, 328817 effective words/s
# CPU times: user 15min 38s, sys: 8.3 s, total: 15min 46s
# Wall time: 2min 36s

# %%
# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
#model_name = "300features_40minwords_10context"
#model.save(model_name)

# %%
# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)
# Out:
# 2017-07-18 16:09:25,559 : INFO : precomputing L2-norms of word weight vectors

# %%
model.most_similar("women")
# Out:
# [('females', 0.656234860420227),
#  ('lesbians', 0.5949513912200928),
#  ('woman', 0.5667258501052856),
#  ('men', 0.5605068802833557),
#  ('males', 0.5595449209213257),
#  ('girls', 0.5456187725067139),
#  ('ladies', 0.5178864002227783),
#  ('prostitutes', 0.5105611085891724),
#  ('gals', 0.508052408695221),
#  ('gays', 0.5025300979614258)]

# %%
# %matplotlib inline
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

def plot_with_labels(low_dim_embs, labels, filename='tsne_skipgram.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform((model[model.wv.vocab])[:plot_only, :])

# %%
labels = [list(model.wv.vocab.items())[i][0] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)
print("Rendered")

#list(model.wv.vocab.items())[1]
# Out:
# Rendered

# %%
model.most_similar(['man'])
# Out:
# [('mans', 0.5307004451751709),
#  ('chap', 0.5112670660018921),
#  ('men', 0.5075519680976868),
#  ('lad', 0.497279554605484),
#  ('woman', 0.4909399747848511),
#  ('guy', 0.4899998605251312),
#  ('trapper', 0.482507586479187),
#  ('person', 0.459179550409317),
#  ('simpleton', 0.4428187310695648),
#  ('librarian', 0.4422321617603302)]

# %%
model.most_similar(['girl', 'father'], ['boy'], topn=3)
# Out:
# [('mother', 0.6128566265106201),
#  ('husband', 0.5500962734222412),
#  ('mom', 0.5209158658981323)]

# %%
more_examples = ["laugh fun fear", "big bigger bad", "going went being"] 
for example in more_examples:
    a, b, x = example.split()
    predicted = model.most_similar([x, b], [a])[0][0]
    print (a+ " is to " + b + " as " + x + " is to " + predicted)
# Out:
# laugh is to fun as fear is to danger
# big is to bigger as bad is to worse
# going is to went as being is to became

# %% [markdown]
# ### Excercise. Try vector operations

# %%
# Replace word1,word2,word3 with your words to see how vector operations work

model.most_similar(positive=['word1', 'word2'], negative=['word3'], topn=1)

# %%
#Replace w1 w2 w3 w4 with your words to find most improper word

model.doesnt_match("w1 w2 w3 w4".split())

# %%
# Try adjectives related to sentiment to find closest words

model.most_similar("awful")
# Out:
# [('terrible', 0.6924468874931335),
#  ('horrid', 0.6541263461112976),
#  ('horrible', 0.651119589805603),
#  ('abysmal', 0.6358823180198669),
#  ('horrendous', 0.6302447319030762),
#  ('atrocious', 0.6273396015167236),
#  ('lousy', 0.6112151741981506),
#  ('dreadful', 0.607136607170105),
#  ('appalling', 0.5970708131790161),
#  ('godawful', 0.5799492001533508)]

# %% [markdown]
# # Glove
# http://www-nlp.stanford.edu/pubs/glove.pdf – Jeffrey Pennington, Richard Socher, Christopher D. Manning 2014.
# http://nlp.stanford.edu/projects/glove/ – pre-trained word vectors and some theory
#
#
# ### What is GloVe?
# *GloVe* is an unsupervised learning algorithm for obtaining vector representations for words. Training is performed on aggregated global word-word co-occurrence statistics from a corpus, and the resulting representations showcase interesting linear substructures of the word vector space.
# More detailed explanation https://blog.acolyer.org/2016/04/22/glove-global-vectors-for-word-representation/
#
# ![alt text](http://building-babylon.net/wp-content/uploads/2016/02/glove-matrix-factorisation-3.jpg)
#
# ### Difference with word2vec
# Word2Vec and GloVe learn geometrical encodings (vectors) of words from their co-occurrence information (how frequently they appear together in large text corpora). They differ in that word2vec is a "predictive" model, whereas GloVe is a "count-based" model.
#
# Predictive models learn their vectors in order to improve their predictive ability of Loss(target word | context words; Vectors), i.e. the loss of predicting the target words from the context words given the vector representations. In word2vec, this is cast as a feed-forward neural network and optimized as such using SGD, etc.
#
# Count-based models learn their vectors by essentially doing dimensionality reduction on the co-occurrence counts matrix. They first construct a large matrix of (words x context) co-occurrence information, i.e. for each "word" (the rows), you count how frequently we see this word in some "context" (the columns) in a large corpus.  The number of "contexts" is of course large, since it is essentially combinatorial in size. So then they factorize this matrix to yield a lower-dimensional (word x features) matrix, where each row now yields a vector representation for each word. In general, this is done by minimizing a "reconstruction loss" which tries to find the lower-dimensional representations which can explain most of the variance in the high-dimensional data. In the specific case of GloVe, the counts matrix is preprocessed by normalizing the counts and log-smoothing them. This turns out to be A Good Thing in terms of the quality of the learned representations.
#
# However, as pointed out, when we control for all the training hyper-parameters, the embeddings generated using the two methods tend to perform very similarly in downstream NLP tasks. The additional benefits of GloVe over word2vec is that it is easier to parallelize the implementation which means it's easier to train over more data, which, with these models, is always A Good Thing.
#
# ### When to use?
# Works better with neural nets, such as RNN/LSTM and CNN. On machine learning algorithms a result will be worse than on bag of words or on vectorizers.
