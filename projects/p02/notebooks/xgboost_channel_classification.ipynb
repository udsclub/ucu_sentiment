# %%
import string
import pandas as pd
import numpy as np
import os
import re
from datetime import date
from fastnumbers import isfloat, isint
from sklearn.feature_extraction.text import TfidfVectorizer

dir_train = '../data'

mappings = {
    'career': 0,
    'theory_and_practice': 1,
    'deep_learning': 2,
    'lang_python': 3,
    '_meetings': 4,
    'kaggle_crackers': 5,
    'big_data': 6,
    'lang_r': 7,
    'nlp': 8,
    'welcome': 9,
    'datasets': 10,
    'bayesian': 11
}


# parameters initialization
VALIDATION_SPLIT = 0.1
RANDOM_SEED = 42

data = pd.read_csv(os.path.join(dir_train, 'train_set.csv'), usecols=range(1,11), parse_dates=['timestamp', 'thread_timestamp'])
data = data[
    data.channel.isin(['career', 'big_data', 'deep_learning', 'kaggle_crackers',
           'lang_python',  'lang_r', 'nlp', 'theory_and_practice', 'welcome', 'bayesian', '_meetings', 'datasets']) &
    data.main_msg
]

# data_train = data.
date_before = date(2017, 4, 1)
train = data[data['timestamp'] <= date_before]
val = data[data['timestamp'] > date_before]

train_data = train[['channel', 'text']].reset_index()[['channel', 'text']]
train_data['channel'] = train_data.channel.map(mappings)
train_data = train_data.sort_values('channel').reset_index()[['channel', 'text']]

val_data = val[['channel', 'text']].reset_index()[['channel', 'text']]
val_data['channel'] = val_data.channel.map(mappings)
val_data = val_data.sort_values('channel').reset_index()[['channel', 'text']]

train_data.text = train_data.text.astype(str)\
    .apply(lambda x: re.sub('(<\S+>:?)|(\s?:\S+:\s?)|(&gt;)|([\w\.]*@[\w\.]*)', ' ', x))\
    .apply(lambda x: re.sub('\s+', ' ', x))
train_data = train_data[~train_data.text.apply(lambda x: isfloat(x) or isint(x) or len(x) < 20)]

val_data.text = val_data.text.astype(str)\
    .apply(lambda x: re.sub('(<\S+>:?)|(\s?:\S+:\s?)|(&gt;)|([\w\.]*@[\w\.]*)', ' ', x))\
    .apply(lambda x: re.sub('\s+', ' ', x))
val_data = val_data[~val_data.text.apply(lambda x: isfloat(x) or isint(x) or len(x) < 20)]

train_text = train_data['text'].astype(str).apply(lambda x: x.lower())
train_labels =  np.asarray(train_data['channel'], dtype='int8')

val_text = val_data['text'].astype(str).apply(lambda x: x.lower())
val_labels = np.asarray(val_data['channel'], dtype='int8')

vectorizer = TfidfVectorizer(analyzer = 'char', max_features = 1000000, ngram_range = (1, 4))
train_matrix = vectorizer.fit_transform(train_text)
val_matrix = vectorizer.transform(val_text)

# %%
import xgboost as xgb
xgb_train = xgb.DMatrix(train_matrix, label=train_labels)
xgb_val = xgb.DMatrix(val_matrix, label=val_labels)

params = {
    'eta': 0.1, 
    'seed': 42, 
    'subsample': 0.6, 
    'colsample_bytree': 0.7,
    'objective': 'multi:softmax', 
    'max_depth': 11, 
    'min_child_weight': 1,
    'num_class': 12,
    'eval_metric': 'merror' 
}

eval_matrix = [(xgb_val, 'xgb_val')]

final_gb = xgb.train(params, xgb_train, num_boost_round = 1000, evals = eval_matrix, early_stopping_rounds=5,
                    verbose_eval=1)
# Out:
# [0]	xgb_val-merror:0.594336
# Will train until xgb_val-merror hasn't improved in 5 rounds.
# [1]	xgb_val-merror:0.5558
# [2]	xgb_val-merror:0.541446
# [3]	xgb_val-merror:0.531488
# [4]	xgb_val-merror:0.52554
# [5]	xgb_val-merror:0.51791
# [6]	xgb_val-merror:0.511832
# [7]	xgb_val-merror:0.510927
# [8]	xgb_val-merror:0.508987
# [9]	xgb_val-merror:0.507048
# [10]	xgb_val-merror:0.507048
# [11]	xgb_val-merror:0.503685
# [12]	xgb_val-merror:0.503815
# [13]	xgb_val-merror:0.503168
# [14]	xgb_val-merror:0.501616
# [15]	xgb_val-merror:0.500065
# [16]	xgb_val-merror:0.500453
# [17]	xgb_val-merror:0.497996
# [18]	xgb_val-merror:0.496961
# [19]	xgb_val-merror:0.496185
# [20]	xgb_val-merror:0.49528
# [21]	xgb_val-merror:0.494116
# [22]	xgb_val-merror:0.493987
# [23]	xgb_val-merror:0.492823
# [24]	xgb_val-merror:0.491271
# [25]	xgb_val-merror:0.489978
# [26]	xgb_val-merror:0.490366
# [27]	xgb_val-merror:0.488038
# [28]	xgb_val-merror:0.488038
# [29]	xgb_val-merror:0.486616
# [30]	xgb_val-merror:0.485323
# [31]	xgb_val-merror:0.485193
# [32]	xgb_val-merror:0.484288
# [33]	xgb_val-merror:0.482478
# [34]	xgb_val-merror:0.48196
# [35]	xgb_val-merror:0.481314
# [36]	xgb_val-merror:0.481572
# [37]	xgb_val-merror:0.48196
# [38]	xgb_val-merror:0.480538
# [39]	xgb_val-merror:0.479374
# [40]	xgb_val-merror:0.479891
# [41]	xgb_val-merror:0.477952
# [42]	xgb_val-merror:0.47834
# [43]	xgb_val-merror:0.477693
# [44]	xgb_val-merror:0.477693
# [45]	xgb_val-merror:0.476788
# [46]	xgb_val-merror:0.475236
# [47]	xgb_val-merror:0.474977
# [48]	xgb_val-merror:0.475495
# [49]	xgb_val-merror:0.475495
# [50]	xgb_val-merror:0.474589
# [51]	xgb_val-merror:0.473426
# [52]	xgb_val-merror:0.473555
# [53]	xgb_val-merror:0.472391
# [54]	xgb_val-merror:0.472391
# [55]	xgb_val-merror:0.471615
# [56]	xgb_val-merror:0.47071
# [57]	xgb_val-merror:0.470969
# [58]	xgb_val-merror:0.470451
# [59]	xgb_val-merror:0.470193
# [60]	xgb_val-merror:0.469675
# [61]	xgb_val-merror:0.468124
# [62]	xgb_val-merror:0.468512
# [63]	xgb_val-merror:0.469675
# [64]	xgb_val-merror:0.470063
# [65]	xgb_val-merror:0.468124
# [66]	xgb_val-merror:0.467348
# [67]	xgb_val-merror:0.466701
# [68]	xgb_val-merror:0.466055
# [69]	xgb_val-merror:0.466572
# [70]	xgb_val-merror:0.466701
# [71]	xgb_val-merror:0.46502
# [72]	xgb_val-merror:0.465537
# [73]	xgb_val-merror:0.464891
# [74]	xgb_val-merror:0.464373
# [75]	xgb_val-merror:0.464244
# [76]	xgb_val-merror:0.463468
# [77]	xgb_val-merror:0.462434
# [78]	xgb_val-merror:0.462046
# [79]	xgb_val-merror:0.461658
# [80]	xgb_val-merror:0.461787
# [81]	xgb_val-merror:0.460623
# [82]	xgb_val-merror:0.461529
# [83]	xgb_val-merror:0.460882
# [84]	xgb_val-merror:0.460494
# [85]	xgb_val-merror:0.459977
# [86]	xgb_val-merror:0.460494
# [87]	xgb_val-merror:0.460365
# [88]	xgb_val-merror:0.460106
# [89]	xgb_val-merror:0.460623
# [90]	xgb_val-merror:0.459977
# Stopping. Best iteration:
# [85]	xgb_val-merror:0.459977
